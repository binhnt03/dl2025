# %% [markdown]
# # Labwork 3: Logistic Regression from scratch
#
# -------------------------------------------------------------------------
#
# In this code notebook, we will recreate the gradient descend without any website packages, just only inbuilt packages for python 3.12 such as:
# ```
#  import math
#  import matplotlib as plt.
# ```

# %%
e = 2.71828

# %%
import math
import matplotlib as plt

# %% [markdown]
# ## The model and its derivatives

# %% [markdown]
# \begin{equation*}
# y_p = w_1\times x_1 + w_2\times x_2 + w_0
# \end{equation*}

# %%
def yp(w0,w1,w2,x1,x2):
    return w1 * x1 + w2 * x2 + w0

# %% [markdown]
# \begin{equation*}
# \frac{\partial y_p}{\partial w_1} = x_1
# \end{equation*}
#
# \begin{equation*}
# \frac{\partial y_p}{\partial w_2} = x_2
# \end{equation*}
#
# \begin{equation*}
# \frac{\partial y_p}{\partial w_0} = 1
# \end{equation*}

# %%
def dyp_dw1(w0,w1,w2,x1,x2):
    return x1

# %%
def dyp_dw2(w0,w1,w2,x1,x2):
    return x2

# %% [markdown]
# ## Sigmoid function, and its derivative
#
# \begin{equation*}
# \sigma(z) = \frac{1}{1+e^{-z}}
# \end{equation*}

# %%
def sigmoid(z):
    return 1 / (1+e**(-z))

# %% [markdown]
# \begin{equation*}
# \frac{d\sigma(z)}{dz} = \frac{z'\times(e^{-z})}{(1+e^{-z})^{2}}
# \end{equation*}

# %%
def dsigmoid(z,dz):
    return (dz*e**(-z))/((1+e**(-z))**2)

# %%
def dsigmoid_dw0(z):
    return (e**(-z))/((1+e**(-z))**2)

# %% [markdown]
# ## Loss function for one selected data point
#
# \begin{equation*}
# L_i = -(y_i\times log(\sigma(y_p)) + (1-y_i)\times log(1-\sigma(y_p)))
# \end{equation*}

# %%
def loss(w0,w1,w2,x1,x2,yi):
    return -(yi*math.log(sigmoid(yp(w0,w1,w2,x1,x2)),e) + (1-yi)*math.log(1-sigmoid(yp(w0,w1,w2,x1,x2)),e))

# %% [markdown]
# The derivative for the loss function:
#
# \begin{equation*}
# \frac{\partial L_i}{\partial w_j} = -(y_i\times \frac{\frac{\partial\sigma(y_p)}{\partial w_j}}{\sigma(y_p)} + (y_i-1)\frac{\frac{\partial\sigma(y_p)}{\partial w_j}}{1-\sigma(y_p)})
# \end{equation*}

# %%
def dloss_dw1(w0,w1,w2,x1,x2,yi):
    return -(
            yi* ( dsigmoid(yp(w0,w1,w2,x1,x2),dyp_dw1(w0,w1,w2,x1,x2)) / sigmoid(yp(w0,w1,w2,x1,x2)) )
             + (1-yi)*( (-dsigmoid(yp(w0,w1,w2,x1,x2),dyp_dw1(w0,w1,w2,x1,x2))) / (1-sigmoid(yp(w0,w1,w2,x1,x2))) )
             )

# %%
def dloss_dw2(w0,w1,w2,x1,x2,yi):
    return -(
            yi* ( dsigmoid(yp(w0,w1,w2,x1,x2),dyp_dw2(w0,w1,w2,x1,x2)) / sigmoid(yp(w0,w1,w2,x1,x2)) )
             + (1-yi)*( (-dsigmoid(yp(w0,w1,w2,x1,x2),dyp_dw2(w0,w1,w2,x1,x2))) / (1-sigmoid(yp(w0,w1,w2,x1,x2))) )
             )

# %%
def dloss_dw0(w0,w1,w2,x1,x2,yi):

    return -(
            (1-yi)*( (-dsigmoid_dw0(yp(w0,w1,w2,x1,x2))) / (1-sigmoid(yp(w0,w1,w2,x1,x2))) )
             +(yi* ( dsigmoid_dw0(yp(w0,w1,w2,x1,x2)) / sigmoid(yp(w0,w1,w2,x1,x2)) )))

# %% [markdown]
# Cross Entropy loss of the model

# %%
def nloss(w0,w1,w2,x1,x2,yi):
    sum = 0
    for i in range(len(x1)):
        sum = sum + loss(w0,w1,w2,x1[i],x2[i],yi[i])
    return sum / len(x1)

# %% [markdown]
# Derive the function in the sum:

# %%
def dnloss_dw1(w0,w1,w2,x1,x2,yi):
    sum = 0
    for i in range(len(x1)):
        sum = sum + dloss_dw1(w0,w1,w2,x1[i],x2[i],yi[i])
    return sum / len(x1)

# %%
def dnloss_dw2(w0,w1,w2,x1,x2,yi):
    sum = 0
    for i in range(len(x1)):
        sum = sum + dloss_dw2(w0,w1,w2,x1[i],x2[i],yi[i])
    return sum / len(x1)

# %%
def dnloss_dw0(w0,w1,w2,x1,x2,yi):
    sum = 0
    for i in range(len(x1)):
        sum = sum + dloss_dw0(w0,w1,w2,x1[i],x2[i],yi[i])
    return sum / len(x1)

# %% [markdown]
# Perform the gradient descend algorithm, and print the values for weights, losses for each iteration.

# %%
def gd(w0,w1,w2,x1,x2,yi,lr,t):
    i = 1
    while True:
        l0 = dnloss_dw0(w0,w1,w2,x1,x2,yi)
        l1 = dnloss_dw1(w0,w1,w2,x1,x2,yi)
        l2 = dnloss_dw2(w0,w1,w2,x1,x2,yi)
        print("------------------------------")
        print("Step "+str(i))
        print("------------------------------")
        print("w0 = "+str(w0)+"; w1 = "+str(w1)+"; w2 = "+str(w2))
        print("loss w.r.t w0: "+str(l0))
        print("loss w.r.t w1: "+str(l1))
        print("loss w.r.t w2: "+str(l2))

        w0 = w0 - lr * l0
        w1 = w1 - lr * l1
        w2 = w2 - lr * l2
        i = i + 1
        if ( (l0 < t and l1 < t and l2 < t and l0 > -t and l1 > -t and l2 > -t)):
            print("")
            print("------------| GRADIENT DESCEND SUCCESS! |-----------")
            print("We have hit bottom after "+str(i-1)+" steps")
            break
        elif i == 200:
            print("")
            print("------------| GRADIENT DESCEND FAILURE! |-----------")
            print("We have not hit bottom, time to try again! ")
            break

# %% [markdown]
# ## Load the csv file
# Each line is printed as a tuple element in the list

# %%
with open('loan2.csv', 'r') as f:
    results = []
    for line in f:
            words = line.split(',')
            results.append(words)
    print(results)
# Out:
# [['Experience', ' Salary', ' Loan\n'], ['3', '4', '1\n'], ['2.5', '4', '1\n'], ['1', '4', '0\n'], ['2.5', '5', '1\n'], ['2', '5', '1\n'], ['1.5', '5', '0\n'], ['0.5', '5', '0\n'], ['1.75', '6', '1\n'], ['0.25', '6', '0\n'], ['1', '7', '1\n'], ['0.25', '7', '0\n'], ['0.20', '7', '0\n'], ['0.15', '7', '0\n'], ['2', '8', '1\n'], ['1', '8', '0\n'], ['0.15', '8', '0\n'], ['0.10', '8', '0\n'], ['0.5', '9', '1\n'], ['1', '10', '1']]

# %% [markdown]
# The experience is used as the $x_1$, salary as $x_2$, and loan as $y_i$.

# %%
x1 = []
x2 = []
yi = []
for i in range(1,len(results)):
    x1.append(float(results[i][0]))
    x2.append(float(results[i][1]))
    yi.append(int(results[i][2]))
print(x1)
print(x2)
print(yi)
# Out:
# [3.0, 2.5, 1.0, 2.5, 2.0, 1.5, 0.5, 1.75, 0.25, 1.0, 0.25, 0.2, 0.15, 2.0, 1.0, 0.15, 0.1, 0.5, 1.0]
# [4.0, 4.0, 4.0, 5.0, 5.0, 5.0, 5.0, 6.0, 6.0, 7.0, 7.0, 7.0, 7.0, 8.0, 8.0, 8.0, 8.0, 9.0, 10.0]
# [1, 1, 0, 1, 1, 0, 0, 1, 0, 1, 0, 0, 0, 1, 0, 0, 0, 1, 1]

# %% [markdown]
# ## Testing gradient descend:
#
# Sigmoid was too small, maybe I need to change the learning rate. It is best to not make the weights too small, since it can cause the sigmoid function to go wrong. For the lowest possible loss, I decided to increase the threshold to 0.27, most learning rate I tried did not reach the lower threshold.

# %%
gd(0,1,2,x1,x2,yi,0.007,0.27)
# Out:
# ------------------------------
# Step 1
# ------------------------------
# w0 = 0; w1 = 1; w2 = 2
# loss w.r.t w0: 0.5263040189528949
# loss w.r.t w1: 0.26840543218501844
# loss w.r.t w2: 3.4210020035298947
# ------------------------------
# Step 2
# ------------------------------
# w0 = -0.0036841281326702646; w1 = 0.9981211619747049; w2 = 1.9760529859752907
# loss w.r.t w0: 0.5263026599105598
# loss w.r.t w1: 0.2684036570035977
# loss w.r.t w2: 3.420996052386192
# ------------------------------
# Step 3
# ------------------------------
# w0 = -0.007368246752044183; w1 = 0.9962423363756797; w2 = 1.9521060136085873
# loss w.r.t w0: 0.526301141445617
# loss w.r.t w1: 0.268401678001391
# loss w.r.t w2: 3.420989388428564
# ------------------------------
# Step 4
# ------------------------------
# w0 = -0.011052354742163503; w1 = 0.9943635246296699; w2 = 1.9281590878895873
# loss w.r.t w0: 0.526299443936534
# loss w.r.t w1: 0.2683994711686987
# loss w.r.t w2: 3.4209819198662053
# ------------------------------
# Step 5
# ------------------------------
# w0 = -0.014736450849719241; w1 = 0.992484728331489; w2 = 1.9042122144505238
# loss w.r.t w0: 0.526297546042504
# loss w.r.t w1: 0.26839701018087797
# loss w.r.t w2: 3.420973548859579
# ------------------------------
# Step 6
# ------------------------------
# w0 = -0.018420533672016768; w1 = 0.9906059492602229; w2 = 1.8802653996085068
# loss w.r.t w0: 0.5262954233582684
# loss w.r.t w1: 0.26839426519539034
# loss w.r.t w2: 3.42096416157557
# ------------------------------
# Step 7
# ------------------------------
# w0 = -0.02210460163552465; w1 = 0.9887271894038552; w2 = 1.8563186504774778
# loss w.r.t w0: 0.5262930490423908
# loss w.r.t w1: 0.2683912031631026
# loss w.r.t w2: 3.4209536343812075
# ------------------------------
# Step 8
# ------------------------------
# w0 = -0.025788652978821384; w1 = 0.9868484509817135; w2 = 1.8323719750368093
# loss w.r.t w0: 0.52629039224806
# loss w.r.t w1: 0.26838778695097326
# loss w.r.t w2: 3.420941822375278
# ------------------------------
# Step 9
# ------------------------------
# w0 = -0.029472685724557805; w1 = 0.9849697364730566; w2 = 1.8084253822801823
# loss w.r.t w0: 0.5262874185299561
# loss w.r.t w1: 0.2683839748588
# loss w.r.t w2: 3.4209285639139266
# ------------------------------
# Step 10
# ------------------------------
# w0 = -0.0331566976542675; w1 = 0.9830910486490451; w2 = 1.7844788823327848
# loss w.r.t w0: 0.5262840892187327
# loss w.r.t w1: 0.26837972041824865
# loss w.r.t w2: 3.4209136771482904
# ------------------------------
# Step 11
# ------------------------------
# w0 = -0.03684068627879863; w1 = 0.9812123906061173; w2 = 1.7605324865927467
# loss w.r.t w0: 0.526280360506423
# loss w.r.t w1: 0.2683749714127577
# loss w.r.t w2: 3.420896954307526
# ------------------------------
# Step 12
# ------------------------------
# w0 = -0.04052464880234359; w1 = 0.979333765806228; w2 = 1.736586207912594
# loss w.r.t w0: 0.526276183325287
# loss w.r.t w1: 0.26836966956783753
# loss w.r.t w2: 3.420878162574309
# ------------------------------
# Step 13
# ------------------------------
# w0 = -0.0442085820856206; w1 = 0.9774551781192531; w2 = 1.7126400607745738
# loss w.r.t w0: 0.5262715021043183
# loss w.r.t w1: 0.2683637494131297
# loss w.r.t w2: 3.420857036232012
# ------------------------------
# Step 14
# ------------------------------
# w0 = -0.047892482600350825; w1 = 0.9755766318733612; w2 = 1.6886940615209496
# loss w.r.t w0: 0.5262662543420223
# loss w.r.t w1: 0.26835713770223385
# loss w.r.t w2: 3.420833275569308
# ------------------------------
# Step 15
# ------------------------------
# w0 = -0.05157634638074498; w1 = 0.9736981319094455; w2 = 1.6647482285919644
# loss w.r.t w0: 0.5262603694410708
# loss w.r.t w1: 0.26834975230353897
# loss w.r.t w2: 3.4208065401830523
# ------------------------------
# Step 16
# ------------------------------
# w0 = -0.055260168966832474; w1 = 0.9718196836433207; w2 = 1.640802582810683
# loss w.r.t w0: 0.5262537676835081
# loss w.r.t w1: 0.26834150110784016
# loss w.r.t w2: 3.4207764437484856
# ------------------------------
# Step 17
# ------------------------------
# w0 = -0.05894394534061703; w1 = 0.9699412931355659; w2 = 1.6168571477044436
# loss w.r.t w0: 0.5262463590290507
# loss w.r.t w1: 0.26833228083155
# loss w.r.t w2: 3.4207425477243785
# ------------------------------
# Step 18
# ------------------------------
# w0 = -0.06262766985382039; w1 = 0.968062967169745; w2 = 1.592911949870373
# loss w.r.t w0: 0.5262380417156904
# loss w.r.t w1: 0.2683219756276867
# loss w.r.t w2: 3.4207043539082433
# ------------------------------
# Step 19
# ------------------------------
# w0 = -0.06631133614583022; w1 = 0.9661847133403513; w2 = 1.5689670193930152
# loss w.r.t w0: 0.5262287006125755
# loss w.r.t w1: 0.26831045545919496
# loss w.r.t w2: 3.420661295477184
# ------------------------------
# Step 20
# ------------------------------
# w0 = -0.06999493705011825; w1 = 0.9643065401521369; w2 = 1.545022390324675
# loss w.r.t w0: 0.5262182054800789
# loss w.r.t w1: 0.26829757438966767
# loss w.r.t w2: 3.420612727820973
# ------------------------------
# Step 21
# ------------------------------
# w0 = -0.0736784644884788; w1 = 0.9624284571314092; w2 = 1.5210781012299281
# loss w.r.t w0: 0.5262064088340792
# loss w.r.t w1: 0.26828316855470064
# loss w.r.t w2: 3.420557916811917
# ------------------------------
# Step 22
# ------------------------------
# w0 = -0.07736190935031735; w1 = 0.9605504749515263; w2 = 1.4971341958122448
# loss w.r.t w0: 0.5261931435674337
# loss w.r.t w1: 0.2682670538889786
# loss w.r.t w2: 3.4204960258146135
# ------------------------------
# Step 23
# ------------------------------
# w0 = -0.08104526135528939; w1 = 0.9586726055743034; w2 = 1.4731907236315425
# loss w.r.t w0: 0.5261782202135837
# loss w.r.t w1: 0.26824902357750124
# loss w.r.t w2: 3.4204261005982968
# ------------------------------
# Step 24
# ------------------------------
# w0 = -0.08472850889678447; w1 = 0.9567948624092609; w2 = 1.4492477409273543
# loss w.r.t w0: 0.5261614238389268
# loss w.r.t w1: 0.26822884517127654
# loss w.r.t w2: 3.420347052144664
# ------------------------------
# Step 25
# ------------------------------
# w0 = -0.08841163886365697; w1 = 0.954917260493062; w2 = 1.4253053115623417
# loss w.r.t w0: 0.5261425104377088
# loss w.r.t w1: 0.26820625731612446
# loss w.r.t w2: 3.420257636463956
# ------------------------------
# Step 26
# ------------------------------
# w0 = -0.09209463643672093; w1 = 0.9530398166918491; w2 = 1.401363508107094
# loss w.r.t w0: 0.5261212028151931
# loss w.r.t w1: 0.2681809660416481
# loss w.r.t w2: 3.4201564314173267
# ------------------------------
# Step 27
# ------------------------------
# w0 = -0.09577748485642729; w1 = 0.9511625499295576; w2 = 1.3774224130871728
# loss w.r.t w0: 0.5260971858538462
# loss w.r.t w1: 0.2681526405826678
# loss w.r.t w2: 3.420041809855963
# ------------------------------
# Step 28
# ------------------------------
# w0 = -0.0994601651574042; w1 = 0.949285481445479; w2 = 1.353482120418181
# loss w.r.t w0: 0.5260701010713218
# loss w.r.t w1: 0.268120908623572
# loss w.r.t w2: 3.419911908512
# ------------------------------
# Step 29
# ------------------------------
# w0 = -0.10314265586490345; w1 = 0.947408635085114; w2 = 1.329542737058597
# loss w.r.t w0: 0.5260395403657161
# loss w.r.t w1: 0.2680853509282443
# loss w.r.t w2: 3.4197645919739834
# ------------------------------
# Step 30
# ------------------------------
# w0 = -0.10682493264746347; w1 = 0.9455320376286163; w2 = 1.3056043849147791
# loss w.r.t w0: 0.5260050387950932
# loss w.r.t w1: 0.2680454952273297
# loss w.r.t w2: 3.419597410745807
# ------------------------------
# Step 31
# ------------------------------
# w0 = -0.11050696791902913; w1 = 0.943655719162025; w2 = 1.2816672030395584
# loss w.r.t w0: 0.5259660662802011
# loss w.r.t w1: 0.2680008093080261
# loss w.r.t w2: 3.419407552717634
# ------------------------------
# Step 32
# ------------------------------
# w0 = -0.11418873038299053; w1 = 0.9417797134968687; w2 = 1.257731350170535
# loss w.r.t w0: 0.5259220180145517
# loss w.r.t w1: 0.26795069314965914
# loss w.r.t w2: 3.4191917865928243
# ------------------------------
# Step 33
# ------------------------------
# w0 = -0.1178701845090924; w1 = 0.9399040586448211; w2 = 1.2337970076643852
# loss w.r.t w0: 0.5258722034165179
# loss w.r.t w1: 0.26789447000988426
# loss w.r.t w2: 3.4189463962315396
# ------------------------------
# Step 34
# ------------------------------
# w0 = -0.12155128993300802; w1 = 0.9380287973547519; w2 = 1.2098643828907645
# loss w.r.t w0: 0.52581583335667
# loss w.r.t w1: 0.2678313762863123
# loss w.r.t w2: 3.4186671041114316
# ------------------------------
# Step 35
# ------------------------------
# w0 = -0.1252320007665047; w1 = 0.9361539777207477; w2 = 1.1859337131619845
# loss w.r.t w0: 0.5257520054052656
# loss w.r.t w1: 0.26776054999918464
# loss w.r.t w2: 3.4183489822234217
# ------------------------------
# Step 36
# ------------------------------
# w0 = -0.12891226480434156; w1 = 0.9342796538707534; w2 = 1.1620052702864205
# loss w.r.t w0: 0.5256796867772785
# loss w.r.t w1: 0.2676810176986844
# loss w.r.t w2: 3.417986348234074
# ------------------------------
# Step 37
# ------------------------------
# w0 = -0.13259202261178252; w1 = 0.9324058867468626; w2 = 1.138079365848782
# loss w.r.t w0: 0.5255976945964091
# loss w.r.t w1: 0.26759167956656943
# loss w.r.t w2: 3.4175726443334864
# ------------------------------
# Step 38
# ------------------------------
# w0 = -0.13627120647395738; w1 = 0.9305327449898967; w2 = 1.1141563573384476
# loss w.r.t w0: 0.5255046730567243
# loss w.r.t w1: 0.26749129247097686
# loss w.r.t w2: 3.4171002958998877
# ------------------------------
# Step 39
# ------------------------------
# w0 = -0.13994973918535444; w1 = 0.9286603059425999; w2 = 1.0902366552671485
# loss w.r.t w0: 0.5253990669812899
# loss w.r.t w1: 0.267378450681456
# loss w.r.t w2: 3.416560546521998
# ------------------------------
# Step 40
# ------------------------------
# w0 = -0.14362753265422348; w1 = 0.9267886567878296; w2 = 1.0663207314414946
# loss w.r.t w0: 0.5252790911927192
# loss w.r.t w1: 0.26725156391440236
# loss w.r.t w2: 3.415943265300105
# ------------------------------
# Step 41
# ------------------------------
# w0 = -0.1473044862925725; w1 = 0.9249178958404288; w2 = 1.042409128584394
# loss w.r.t w0: 0.525142695037004
# loss w.r.t w1: 0.26710883234435095
# loss w.r.t w2: 3.415236721802562
# ------------------------------
# Step 42
# ------------------------------
# w0 = -0.15098048515783152; w1 = 0.9230481340140184; w2 = 1.018502471531776
# loss w.r.t w0: 0.5249875212830054
# loss w.r.t w1: 0.26694821815539355
# loss w.r.t w2: 3.414427323153479
# ------------------------------
# Step 43
# ------------------------------
# w0 = -0.15465539780681256; w1 = 0.9211794964869306; w2 = 0.9946014802697017
# loss w.r.t w0: 0.5248108585126355
# loss w.r.t w1: 0.2667674131599238
# loss w.r.t w2: 3.413499306904771
# ------------------------------
# Step 44
# ------------------------------
# w0 = -0.15832907381640102; w1 = 0.9193121245948112; w2 = 0.9707069851213683
# loss w.r.t w0: 0.5246095859883659
# loss w.r.t w1: 0.2665638019525804
# loss w.r.t w2: 3.4124343823472953
# ------------------------------
# Step 45
# ------------------------------
# w0 = -0.16200134091831958; w1 = 0.9174461779811431; w2 = 0.9468199444449372
# loss w.r.t w0: 0.5243801098382853
# loss w.r.t w1: 0.26633442000139845
# loss w.r.t w2: 3.41121131175298
# ------------------------------
# Step 46
# ------------------------------
# w0 = -0.16567200168718757; w1 = 0.9155818370411334; w2 = 0.9229414652626664
# loss w.r.t w0: 0.5241182892486179
# loss w.r.t w1: 0.266075906014075
# loss w.r.t w2: 3.409805421817439
# ------------------------------
# Step 47
# ------------------------------
# w0 = -0.1693408297119279; w1 = 0.9137193056990348; w2 = 0.8990728273099443
# loss w.r.t w0: 0.5238193511897871
# loss w.r.t w1: 0.2657844478493897
# loss w.r.t w2: 3.408188034201722
# ------------------------------
# Step 48
# ------------------------------
# w0 = -0.17300756517025642; w1 = 0.9118588145640891; w2 = 0.8752155110705323
# loss w.r.t w0: 0.5234777920361918
# loss w.r.t w1: 0.2654557211783319
# loss w.r.t w2: 3.4063258026273053
# ------------------------------
# Step 49
# ------------------------------
# w0 = -0.17667190971450977; w1 = 0.9100006245158409; w2 = 0.8513712304521411
# loss w.r.t w0: 0.5230872642790154
# loss w.r.t w1: 0.26508482004031275
# loss w.r.t w2: 3.404179942494774
# ------------------------------
# Step 50
# ------------------------------
# w0 = -0.1803335205644629; w1 = 0.9081450307755586; w2 = 0.8275419708546777
# loss w.r.t w0: 0.5226404463900012
# loss w.r.t w1: 0.26466617839579476
# loss w.r.t w2: 3.4017053375618973
# ------------------------------
# Step 51
# ------------------------------
# w0 = -0.18399200368919288; w1 = 0.9062923675267881; w2 = 0.8037300334917444
# loss w.r.t w0: 0.5221288937918952
# loss w.r.t w1: 0.2641934817549446
# loss w.r.t w2: 3.398849506952016
# ------------------------------
# Step 52
# ------------------------------
# w0 = -0.18764690594573616; w1 = 0.9044430131545035; w2 = 0.7799380869430803
# loss w.r.t w0: 0.521542868859129
# loss w.r.t w1: 0.2636595679795234
# loss w.r.t w2: 3.395551414870339
# ------------------------------
# Step 53
# ------------------------------
# w0 = -0.19129770602775006; w1 = 0.9025973961786469; w2 = 0.7561692270389879
# loss w.r.t w0: 0.5208711479520275
# loss w.r.t w1: 0.26305631643073746
# loss w.r.t w2: 3.3917401051628606
# ------------------------------
# Step 54
# ------------------------------
# w0 = -0.19494380406341424; w1 = 0.9007560019636317; w2 = 0.7324270463028479
# loss w.r.t w0: 0.5201008037400271
# loss w.r.t w1: 0.2623745247967109
# loss w.r.t w2: 3.387333143674755
# ------------------------------
# Step 55
# ------------------------------
# w0 = -0.19858450968959443; w1 = 0.8989193802900547; w2 = 0.7087157142971247
# loss w.r.t w0: 0.519216961574357
# loss w.r.t w1: 0.2616037732165287
# loss w.r.t w2: 3.3822348538155054
# ------------------------------
# Step 56
# ------------------------------
# w0 = -0.20221902842061493; w1 = 0.897088153877539; w2 = 0.6850400703204161
# loss w.r.t w0: 0.5182025295381729
# loss w.r.t w1: 0.2607322757715156
# loss w.r.t w2: 3.3763343356021087
# ------------------------------
# Step 57
# ------------------------------
# w0 = -0.20584644612738215; w1 = 0.8952630279471384; w2 = 0.6614057299712014
# loss w.r.t w0: 0.5170379031740627
# loss w.r.t w1: 0.2597467201017888
# loss w.r.t w2: 3.369503266765748
# ------------------------------
# Step 58
# ------------------------------
# w0 = -0.20946571144960058; w1 = 0.8934448009064259; w2 = 0.6378192071038411
# loss w.r.t w0: 0.5157006479454648
# loss w.r.t w1: 0.25863209690586525
# loss w.r.t w2: 3.361593497618324
# ------------------------------
# Step 59
# ------------------------------
# w0 = -0.21307561598521882; w1 = 0.8916343762280848; w2 = 0.6142880526205128
# loss w.r.t w0: 0.5141651654516938
# loss w.r.t w1: 0.2573715224913836
# loss w.r.t w2: 3.352434470979979
# ------------------------------
# Step 60
# ------------------------------
# w0 = -0.21667477214338068; w1 = 0.8898327755706451; w2 = 0.590821011323653
# loss w.r.t w0: 0.5124023535433818
# loss w.r.t w1: 0.25594605947991683
# loss w.r.t w2: 3.3418305265970742
# ------------------------------
# Step 61
# ------------------------------
# w0 = -0.22026158861818435; w1 = 0.8880411531542857; w2 = 0.5674281976374734
# loss w.r.t w0: 0.5103792760563882
# loss w.r.t w1: 0.2543345433564014
# loss w.r.t w2: 3.3295581884310947
# ------------------------------
# Step 62
# ------------------------------
# w0 = -0.22383424355057907; w1 = 0.8862608113507908; w2 = 0.5441212903184558
# loss w.r.t w0: 0.5080588651645339
# loss w.r.t w1: 0.2525134259222789
# loss w.r.t w2: 3.3153635853173555
# ------------------------------
# Step 63
# ------------------------------
# w0 = -0.2273906556067308; w1 = 0.8844932173693348; w2 = 0.5209137452212343
# loss w.r.t w0: 0.5053996885362327
# loss w.r.t w1: 0.25045665096859887
# loss w.r.t w2: 3.2989602227524033
# ------------------------------
# Step 64
# ------------------------------
# w0 = -0.23092845342648444; w1 = 0.8827400208125546; w2 = 0.4978210236619675
# loss w.r.t w0: 0.5023558245759457
# loss w.r.t w1: 0.2481355826784688
# loss w.r.t w2: 3.28002740682299
# ------------------------------
# Step 65
# ------------------------------
# w0 = -0.23444494419851605; w1 = 0.8810030717338053; w2 = 0.4748608318142066
# loss w.r.t w0: 0.49887690170448873
# loss w.r.t w1: 0.2455190133243624
# loss w.r.t w2: 3.258209719106184
# ------------------------------
# Step 66
# ------------------------------
# w0 = -0.23793708251044748; w1 = 0.8792844386405347; w2 = 0.4520533637804633
# loss w.r.t w0: 0.49490837098295953
# loss w.r.t w1: 0.24257328346304888
# loss w.r.t w2: 3.2331180483510575
# ------------------------------
# Step 67
# ------------------------------
# w0 = -0.2414014411073282; w1 = 0.8775864256562934; w2 = 0.4294215374420059
# loss w.r.t w0: 0.49039209367503334
# loss w.r.t w1: 0.2392625544436243
# loss w.r.t w2: 3.2043327893899693
# ------------------------------
# Step 68
# ------------------------------
# w0 = -0.24483418576305344; w1 = 0.8759115877751881; w2 = 0.40699120791627613
# loss w.r.t w0: 0.48526733371218084
# loss w.r.t w1: 0.2355492785680954
# loss w.r.t w2: 3.171409902045391
# ------------------------------
# Step 69
# ------------------------------
# w0 = -0.2482310570990387; w1 = 0.8742627428252114; w2 = 0.3847913386019584
# loss w.r.t w0: 0.4794722453050906
# loss w.r.t w1: 0.23139491503139822
# loss w.r.t w2: 3.1338905524715774
# ------------------------------
# Step 70
# ------------------------------
# w0 = -0.25158736281617433; w1 = 0.8726429784199916; w2 = 0.36285410473465735
# loss w.r.t w0: 0.4729459327235077
# loss w.r.t w1: 0.22676093752756374
# loss w.r.t w2: 3.0913149955843324
# ------------------------------
# Step 71
# ------------------------------
# w0 = -0.25489798434523886; w1 = 0.8710556518572987; w2 = 0.341214899765567
# loss w.r.t w0: 0.46563112648303356
# loss w.r.t w1: 0.22161016930293362
# loss w.r.t w2: 3.0432411521587333
# ------------------------------
# Step 72
# ------------------------------
# w0 = -0.2581574022306201; w1 = 0.8695043806721782; w2 = 0.31991221170045586
# loss w.r.t w0: 0.4574774624761814
# loss w.r.t w1: 0.21590846045569514
# loss w.r.t w2: 2.9892679422716335
# ------------------------------
# Step 73
# ------------------------------
# w0 = -0.2613597444679534; w1 = 0.8679930214489883; w2 = 0.2989873361045544
# loss w.r.t w0: 0.44844526560960196
# loss w.r.t w1: 0.2096266880110506
# loss w.r.t w2: 2.9290628314268803
# ------------------------------
# Step 74
# ------------------------------
# w0 = -0.2644988613272206; w1 = 0.8665256346329109; w2 = 0.27848389628456627
# loss w.r.t w0: 0.43850963093000345
# loss w.r.t w1: 0.20274301113896276
# loss w.r.t w2: 2.862392242434261
# ------------------------------
# Step 75
# ------------------------------
# w0 = -0.26756842874373066; w1 = 0.8651064335549381; w2 = 0.25844715058752643
# loss w.r.t w0: 0.42766447569756005
# loss w.r.t w1: 0.1952452545370169
# loss w.r.t w2: 2.789152566880609
# ------------------------------
# Step 76
# ------------------------------
# w0 = -0.2705620800736136; w1 = 0.863739716773179; w2 = 0.23892308261936218
# loss w.r.t w0: 0.4159261284229387
# loss w.r.t w1: 0.1871332298589561
# loss w.r.t w2: 2.709398637651842
# ------------------------------
# Step 77
# ------------------------------
# w0 = -0.2734735629725742; w1 = 0.8624297841641663; w2 = 0.2199572921557993
# loss w.r.t w0: 0.4033359567705924
# loss w.r.t w1: 0.17842075063086832
# loss w.r.t w2: 2.623365931501251
# ------------------------------
# Step 78
# ------------------------------
# w0 = -0.27629691466996836; w1 = 0.8611808389097502; w2 = 0.20159373063529054
# loss w.r.t w0: 0.38996154786632836
# loss w.r.t w1: 0.1691370665991919
# loss w.r.t w2: 2.531482713493237
# ------------------------------
# Step 79
# ------------------------------
# w0 = -0.27902664550503264; w1 = 0.8599968794435559; w2 = 0.18387335164083787
# loss w.r.t w0: 0.3758960641101969
# loss w.r.t w1: 0.15932745510049828
# loss w.r.t w2: 2.43436900690495
# ------------------------------
# Step 80
# ------------------------------
# w0 = -0.281657917953804; w1 = 0.8588815872578524; w2 = 0.16683276859250323
# loss w.r.t w0: 0.36125560475554563
# loss w.r.t w1: 0.1490527702508004
# loss w.r.t w2: 2.332820708058554
# ------------------------------
# Step 81
# ------------------------------
# w0 = -0.2841867071870928; w1 = 0.8578382178660967; w2 = 0.15050302363609336
# loss w.r.t w0: 0.34617467820993153
# loss w.r.t w1: 0.1383878642311313
# loss w.r.t w2: 2.2277791770466098
# ------------------------------
# Step 82
# ------------------------------
# w0 = -0.28660992993456236; w1 = 0.8568695028164788; w2 = 0.1349085693967671
# loss w.r.t w0: 0.3308001758411573
# loss w.r.t w1: 0.12741894244637955
# loss w.r.t w2: 2.1202888211706825
# ------------------------------
# Step 83
# ------------------------------
# w0 = -0.28892553116545044; w1 = 0.8559775702193542; w2 = 0.12006654764857232
# loss w.r.t w0: 0.31528446767360485
# loss w.r.t w1: 0.11624006664301292
# loss w.r.t w2: 2.011447038627071
# ------------------------------
# Step 84
# ------------------------------
# w0 = -0.29113252243916565; w1 = 0.8551638897528531; w2 = 0.10598641837818282
# loss w.r.t w0: 0.2997783577600614
# loss w.r.t w1: 0.10494914278206129
# loss w.r.t w2: 1.9023519541065923
# ------------------------------
# Step 85
# ------------------------------
# w0 = -0.2932309709434861; w1 = 0.8544292457533786; w2 = 0.09266995469943667
# loss w.r.t w0: 0.28442461717328194
# loss w.r.t w1: 0.09364379501882021
# loss w.r.t w2: 1.7940534193746203
# ------------------------------
# Step 86
# ------------------------------
# w0 = -0.29522194326369905; w1 = 0.853773739188247; w2 = 0.08011158076381433
# loss w.r.t w0: 0.2693526690283233
# loss w.r.t w1: 0.08241752046463872
# loss w.r.t w2: 1.687511824854092
# ------------------------------
# Step 87
# ------------------------------
# w0 = -0.2971074119468973; w1 = 0.8531968165449945; w2 = 0.06829899798983569
# loss w.r.t w0: 0.2546747774986273
# loss w.r.t w1: 0.07135644775572679
# loss w.r.t w2: 1.5835676787009312
# ------------------------------
# Step 88
# ------------------------------
# w0 = -0.2988901353893877; w1 = 0.8526973214107044; w2 = 0.05721402423892917
# loss w.r.t w0: 0.24048384955464314
# loss w.r.t w1: 0.060536907951794
# loss w.r.t w2: 1.4829230889422176
# ------------------------------
# Step 89
# ------------------------------
# w0 = -0.3005735223362702; w1 = 0.8522735630550419; w2 = 0.046833562616333646
# loss w.r.t w0: 0.22685274610584938
# loss w.r.t w1: 0.05002389823146505
# loss w.r.t w2: 1.38613463854156
# ------------------------------
# Step 90
# ------------------------------
# w0 = -0.3021614915590112; w1 = 0.8519233957674216; w2 = 0.037130620146542725
# loss w.r.t w0: 0.21383485099587538
# loss w.r.t w1: 0.03987040405561724
# loss w.r.t w2: 1.2936159453829044
# ------------------------------
# Step 91
# ------------------------------
# w0 = -0.3036583355159823; w1 = 0.8516443029390323; w2 = 0.028075308528862395
# loss w.r.t w0: 0.2014655716153953
# loss w.r.t w1: 0.03011746152913163
# loss w.r.t w2: 1.2056475494679455
# ------------------------------
# Step 92
# ------------------------------
# w0 = -0.30506859451729007; w1 = 0.8514334807083284; w2 = 0.019635775682586776
# loss w.r.t w0: 0.1897644350478294
# loss w.r.t w1: 0.0207947948875665
# loss w.r.t w2: 1.1223916218919054
# ------------------------------
# Step 93
# ------------------------------
# w0 = -0.30639694556262487; w1 = 0.8512879171441154; w2 = 0.011779034329343439
# loss w.r.t w0: 0.17873747977336726
# loss w.r.t w1: 0.01192185122176026
# loss w.r.t w2: 1.04390921138476
# ------------------------------
# Step 94
# ------------------------------
# w0 = -0.3076481079210384; w1 = 0.8512044641855632; w2 = 0.0044716698496501195
# loss w.r.t w0: 0.1683797040091073
# loss w.r.t w1: 0.0035090670526524994
# loss w.r.t w2: 0.9701781765832543
# ------------------------------
# Step 95
# ------------------------------
# w0 = -0.3088267658491022; w1 = 0.8511799007161946; w2 = -0.002319577386432661
# loss w.r.t w0: 0.15867740001872166
# loss w.r.t w1: -0.004440771094779916
# loss w.r.t w2: 0.9011104574767486
# ------------------------------
# Step 96
# ------------------------------
# w0 = -0.3099375076492332; w1 = 0.8512109861138581; w2 = -0.0086273505887699
# loss w.r.t w0: 0.14961026708393446
# loss w.r.t w1: -0.011931176484638005
# loss w.r.t w2: 0.8365678200810271
# ------------------------------
# Step 97
# ------------------------------
# w0 = -0.31098477951882075; w1 = 0.8512945043492506; w2 = -0.01448332532933709
# loss w.r.t w0: 0.1411532478439522
# loss w.r.t w1: -0.018970693826258718
# loss w.r.t w2: 0.7763756098513497
# ------------------------------
# Step 98
# ------------------------------
# w0 = -0.3119728522537284; w1 = 0.8514272992060344; w2 = -0.01991795459829654
# loss w.r.t w0: 0.13327807133456052
# loss w.r.t w1: -0.0255717558870521
# loss w.r.t w2: 0.7203343519038498
# ------------------------------
# Step 99
# ------------------------------
# w0 = -0.31290579875307034; w1 = 0.8516063014972438; w2 = -0.024960295061623488
# loss w.r.t w0: 0.12595451206224242
# loss w.r.t w1: -0.03174968584384839
# loss w.r.t w2: 0.6682292429030096
# ------------------------------
# Step 100
# ------------------------------
# w0 = -0.31378748033750603; w1 = 0.8518285492981508; w2 = -0.029637899761944555
# loss w.r.t w0: 0.11915139000664524
# loss w.r.t w1: -0.037521850035791865
# loss w.r.t w2: 0.6198377056331315
# ------------------------------
# Step 101
# ------------------------------
# w0 = -0.31462154006755255; w1 = 0.8520912022484013; w2 = -0.03397676370137648
# loss w.r.t w0: 0.11283734415159064
# loss w.r.t w1: -0.04290695510465427
# loss w.r.t w2: 0.5749352420238921
# ------------------------------
# Step 102
# ------------------------------
# w0 = -0.3154114014766137; w1 = 0.8523915509341339; w2 = -0.03800131039554372
# loss w.r.t w0: 0.10698141443057181
# loss w.r.t w1: -0.047924477169570136
# loss w.r.t w2: 0.5332998422394168
# ------------------------------
# Step 103
# ------------------------------
# w0 = -0.3161602713776277; w1 = 0.8527270222743208; w2 = -0.04173440929121964
# loss w.r.t w0: 0.10155346583447784
# loss w.r.t w1: -0.052594207546489746
# loss w.r.t w2: 0.4947152018188353
# ------------------------------
# Step 104
# ------------------------------
# w0 = -0.316871145638469; w1 = 0.8530951817271463; w2 = -0.045197415703951485
# loss w.r.t w0: 0.09652448536547834
# loss w.r.t w1: -0.056935898587936955
# loss w.r.t w2: 0.4589729775055373
# ------------------------------
# Step 105
# ------------------------------
# w0 = -0.3175468170360274; w1 = 0.8534937330172618; w2 = -0.04841022654649024
# loss w.r.t w0: 0.0918667785738435
# loss w.r.t w1: -0.060968993686938915
# loss w.r.t w2: 0.42587428356508134
# ------------------------------
# Step 106
# ------------------------------
# w0 = -0.3181898844860443; w1 = 0.8539205159730704; w2 = -0.05139134653144581
# loss w.r.t w0: 0.08755408825759745
# loss w.r.t w1: -0.06471242676636194
# loss w.r.t w2: 0.3952305994485764
# ------------------------------
# Step 107
# ------------------------------
# w0 = -0.3188027631038475; w1 = 0.8543735029604349; w2 = -0.054157960727585844
# loss w.r.t w0: 0.0835616539380269
# loss w.r.t w1: -0.06818447824627244
# loss w.r.t w2: 0.366864229840541
# ------------------------------
# Step 108
# ------------------------------
# w0 = -0.31938769468141365; w1 = 0.8548507943081588; w2 = -0.05672601033646963
# loss w.r.t w0: 0.07986622715667487
# loss w.r.t w1: -0.07140267627425957
# loss w.r.t w2: 0.340608431163467
# ------------------------------
# Step 109
# ------------------------------
# w0 = -0.31994675827151037; w1 = 0.8553506130420786; w2 = -0.0591102693546139
# loss w.r.t w0: 0.07644605455692173
# loss w.r.t w1: -0.07438373374928674
# loss w.r.t w2: 0.31630729523120277
# ------------------------------
# Step 110
# ------------------------------
# w0 = -0.3204818806534088; w1 = 0.8558712991783236; w2 = -0.06132442042123232
# loss w.r.t w0: 0.07328083812531688
# loss w.r.t w1: -0.0771435132751096
# loss w.r.t w2: 0.29381546107688816
# ------------------------------
# Step 111
# ------------------------------
# w0 = -0.32099484652028604; w1 = 0.8564113037712494; w2 = -0.06338112864877053
# loss w.r.t w0: 0.07035167984204285
# loss w.r.t w1: -0.07969701360069932
# loss w.r.t w2: 0.27299770981209653
# ------------------------------
# Step 112
# ------------------------------
# w0 = -0.3214873082791803; w1 = 0.8569691828664543; w2 = -0.06529211261745521
# loss w.r.t w0: 0.0676410162735364
# loss w.r.t w1: -0.08205837232993665
# loss w.r.t w2: 0.25372848431693934
#
# ------------| GRADIENT DESCEND SUCCESS! |-----------
# We have hit bottom after 112 steps

# %% [markdown]
# Focal loss of the model:

# %%
def focal_loss(alpha,gamma,w0,w1,w2,x1,x2,yi):
    return -( alpha*((1-loss(w0,w1,w2,x1,x2,yi))**gamma)*math.log(loss(w0,w1,w2,x1,x2,yi),e))

# %% [markdown]
# Partial derivatives of the focal loss with respect to $w_0$, $w_1$, $w_2$:

# %%
def dfocal_loss1(alpha,gamma,w0,w1,w2,x1,x2,yi):
    return -( alpha * gamma * (dloss_dw1(w0,w1,w2,x1,x2,yi)) * ((1-loss(w0,w1,w2,x1,x2,yi))**(gamma-1))*math.log(loss(w0,w1,w2,x1,x2,yi),e) 
             +  alpha * ((1-loss(w0,w1,w2,x1,x2,yi))**gamma) * (dloss_dw1(w0,w1,w2,x1,x2,yi)/(loss(w0,w1,w2,x1,x2,yi))) )

# %%
def dfocal_loss2(alpha,gamma,w0,w1,w2,x1,x2,yi):
    return -( alpha * gamma * (dloss_dw2(w0,w1,w2,x1,x2,yi)) * ((1-loss(w0,w1,w2,x1,x2,yi))**(gamma-1))*math.log(loss(w0,w1,w2,x1,x2,yi),e) 
             +  alpha * ((1-loss(w0,w1,w2,x1,x2,yi))**gamma) * (dloss_dw2(w0,w1,w2,x1,x2,yi)/(loss(w0,w1,w2,x1,x2,yi))) )

# %%
def dfocal_loss0(alpha,gamma,w0,w1,w2,x1,x2,yi):
    return -( alpha * gamma * (dloss_dw0(w0,w1,w2,x1,x2,yi)) * ((1-loss(w0,w1,w2,x1,x2,yi))**(gamma-1))*math.log(loss(w0,w1,w2,x1,x2,yi),e) 
             +  alpha * ((1-loss(w0,w1,w2,x1,x2,yi))**gamma) * (dloss_dw0(w0,w1,w2,x1,x2,yi)/(loss(w0,w1,w2,x1,x2,yi))) )

# %% [markdown]
# With N data points:

# %%
def focal_nloss(alpha,gamma,w0,w1,w2,x1,x2,yi):
    sum = 0
    for i in range(len(x1)):
        sum = sum + focal_loss(alpha,gamma,w0,w1,w2,x1[i],x2[i],yi[i])
    return sum / len(x1)

# %%
def dfocal_nloss1(alpha,gamma,w0,w1,w2,x1,x2,yi):
    sum = 0
    for i in range(len(x1)):
        sum = sum + dfocal_loss1(alpha,gamma,w0,w1,w2,x1[i],x2[i],yi[i])
    return sum / len(x1)

# %%
def dfocal_nloss2(alpha,gamma,w0,w1,w2,x1,x2,yi):
    sum = 0
    for i in range(len(x1)):
        sum = sum + dfocal_loss2(alpha,gamma,w0,w1,w2,x1[i],x2[i],yi[i])
    return sum / len(x1)

# %%
def dfocal_nloss0(alpha,gamma,w0,w1,w2,x1,x2,yi):
    sum = 0
    for i in range(len(x1)):
        sum = sum + dfocal_loss0(alpha,gamma,w0,w1,w2,x1[i],x2[i],yi[i])
    return sum / len(x1)

# %%
def gd2(w0,w1,w2,x1,x2,yi,lr,t,alpha,gamma):
    i = 1
    while True:
        l0 = dfocal_nloss0(alpha,gamma,w0,w1,w2,x1,x2,yi)
        l1 = dfocal_nloss1(alpha,gamma,w0,w1,w2,x1,x2,yi)
        l2 = dfocal_nloss2(alpha,gamma,w0,w1,w2,x1,x2,yi)
        print("------------------------------")
        print("Step "+str(i))
        print("------------------------------")
        print("w0 = "+str(w0)+"; w1 = "+str(w1)+"; w2 = "+str(w2))
        print("loss w.r.t w0: "+str(l0))
        print("loss w.r.t w1: "+str(l1))
        print("loss w.r.t w2: "+str(l2))

        w0 = w0 - lr * l0
        w1 = w1 - lr * l1
        w2 = w2 - lr * l2
        i = i + 1
        if ( (l0 < t and l1 < t and l2 < t and l0 > -t and l1 > -t and l2 > -t)):
            print("")
            print("------------| GRADIENT DESCEND SUCCESS! |-----------")
            print("We have hit bottom after "+str(i-1)+" steps")
            break
        elif i == 200:
            print("")
            print("------------| GRADIENT DESCEND FAILURE! |-----------")
            print("We have not hit bottom, time to try again! ")
            break

# %%
w0 = 0
w1 = 1
w2 = 2
alpha = 0.5
gamma = 2
gd2(w0,w1,w2,x1,x2,yi,0.027,0.08,alpha,gamma)
# Out:
# ------------------------------
# Step 1
# ------------------------------
# w0 = 0; w1 = 1; w2 = 2
# loss w.r.t w0: 14.46403946350764
# loss w.r.t w1: 6.952100745517811
# loss w.r.t w2: 99.2670820061553
# ------------------------------
# Step 2
# ------------------------------
# w0 = -0.3905290655147063; w1 = 0.8122932798710192; w2 = -0.6802112141661931
# loss w.r.t w0: -1.4908343824874297
# loss w.r.t w1: -1.484633167092257
# loss w.r.t w2: -12.341513472246795
# ------------------------------
# Step 3
# ------------------------------
# w0 = -0.3502765371875457; w1 = 0.8523783753825102; w2 = -0.34699035041552967
# loss w.r.t w0: -0.2910326229484898
# loss w.r.t w1: -0.1966122831225098
# loss w.r.t w2: -2.4613082004967155
# ------------------------------
# Step 4
# ------------------------------
# w0 = -0.34241865636793645; w1 = 0.8576869070268179; w2 = -0.28053502900211835
# loss w.r.t w0: -0.15726965932637751
# loss w.r.t w1: -0.09386463505349818
# loss w.r.t w2: -1.3273006235763178
# ------------------------------
# Step 5
# ------------------------------
# w0 = -0.33817237556612423; w1 = 0.8602212521732624; w2 = -0.24469791216555778
# loss w.r.t w0: -0.10123036277196068
# loss w.r.t w1: -0.055472615057377044
# loss w.r.t w2: -0.8553269714278819
# ------------------------------
# Step 6
# ------------------------------
# w0 = -0.3354391557712813; w1 = 0.8617190127798116; w2 = -0.22160408393700498
# loss w.r.t w0: -0.07115075338189754
# loss w.r.t w1: -0.036027534275511475
# loss w.r.t w2: -0.6045216509697623
# ------------------------------
# Step 7
# ------------------------------
# w0 = -0.3335180854299701; w1 = 0.8626917562052504; w2 = -0.2052819993608214
# loss w.r.t w0: -0.05271574806626336
# loss w.r.t w1: -0.024432546453557167
# loss w.r.t w2: -0.45243701820663407
# ------------------------------
# Step 8
# ------------------------------
# w0 = -0.332094760232181; w1 = 0.8633514349594964; w2 = -0.19306619986924228
# loss w.r.t w0: -0.04042350096473159
# loss w.r.t w1: -0.016774635657855717
# loss w.r.t w2: -0.3520758764824121
# ------------------------------
# Step 9
# ------------------------------
# w0 = -0.3310033257061332; w1 = 0.8638043501222585; w2 = -0.18356015120421715
# loss w.r.t w0: -0.03173255469357099
# loss w.r.t w1: -0.011354632354864648
# loss w.r.t w2: -0.2818096760338533
# ------------------------------
# Step 10
# ------------------------------
# w0 = -0.3301465467294068; w1 = 0.8641109251958399; w2 = -0.1759512899513031
# loss w.r.t w0: -0.025317485843921437
# loss w.r.t w1: -0.0073250597955465185
# loss w.r.t w2: -0.23041347465468945
# ------------------------------
# Step 11
# ------------------------------
# w0 = -0.32946297461162094; w1 = 0.8643087018103196; w2 = -0.1697301261356265
# loss w.r.t w0: -0.02042404769426175
# loss w.r.t w1: -0.004218731942572978
# loss w.r.t w2: -0.1915344164236866
# ------------------------------
# Step 12
# ------------------------------
# w0 = -0.32891152532387585; w1 = 0.8644226075727691; w2 = -0.16455869689218694
# loss w.r.t w0: -0.016593656339476712
# loss w.r.t w1: -0.0017577196953805167
# loss w.r.t w2: -0.16133223909827515
# ------------------------------
# Step 13
# ------------------------------
# w0 = -0.32846349660270996; w1 = 0.8644700660045443; w2 = -0.16020272643653352
# loss w.r.t w0: -0.013532567318884461
# loss w.r.t w1: 0.00023355672765486025
# loss w.r.t w2: -0.13736168920528974
# ------------------------------
# Step 14
# ------------------------------
# w0 = -0.3280981172851001; w1 = 0.8644637599728977; w2 = -0.1564939608279907
# loss w.r.t w0: -0.011044505984617968
# loss w.r.t w1: 0.0018715490167908935
# loss w.r.t w2: -0.11799873441361222
# ------------------------------
# Step 15
# ------------------------------
# w0 = -0.3277999156235154; w1 = 0.8644132281494443; w2 = -0.15330799499882317
# loss w.r.t w0: -0.008993658994091812
# loss w.r.t w1: 0.003236659128387587
# loss w.r.t w2: -0.10212641401749009
# ------------------------------
# Step 16
# ------------------------------
# w0 = -0.3275570868306749; w1 = 0.8643258383529778; w2 = -0.15055058182035094
# loss w.r.t w0: -0.007283241422607706
# loss w.r.t w1: 0.004386300826985671
# loss w.r.t w2: -0.0889535504582517
# ------------------------------
# Step 17
# ------------------------------
# w0 = -0.3273604393122645; w1 = 0.8642074082306492; w2 = -0.14814883595797815
# loss w.r.t w0: -0.005842524768287087
# loss w.r.t w1: 0.005362660696942181
# loss w.r.t w2: -0.07790543184048832
#
# ------------| GRADIENT DESCEND SUCCESS! |-----------
# We have hit bottom after 17 steps
